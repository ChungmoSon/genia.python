# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df2 = pd.read_csv('./CS_T_T_STD_COST.csv', encoding='cp949')
df2 = df2[df2['일일대당원가'] > 10000]
df2
# Out:
#         연번  업체아이디  킬로미터당원가  관할행정아이디        입력일자 최종처리자아이디        수정일자  영역분류  \
# 0        1   1041      622      3.0  2012-07-10        1  2012-07-10     1
# 1        2   1000      461     30.0  2012-07-10        1  2012-07-10     2
# 2        3   1006      511     30.0  2012-07-10        1  2012-07-10     2
# 3        4   1010      494     30.0  2012-07-10        1  2012-07-10     2
# 4        5   1011      374     30.0  2012-07-10        1  2012-07-10     2
# ...    ...    ...      ...      ...         ...      ...         ...   ...
# 3274  3275   1036      547      1.0  2012-07-10        1  2012-07-10     1
# 3275  3276   1038      547      1.0  2012-07-10        1  2012-07-10     1
# 3276  3277   1039      547      1.0  2012-07-10        1  2012-07-10     1
# 3277  3278   1025      622      3.0  2012-07-10        1  2012-07-10     1
# 3278  3279   1034      622      3.0  2012-07-10        1  2012-07-10     1
#
#       일일대당원가  평가연도  평가차수
# 0     307546  2012    19
# ...

# %%
#1027,1009,1024,1040
#킬로미터당원가
plt.figure(figsize=(5,3))
sns.boxplot(x='업체아이디' y='킬로미터당원가',data=df3)
plt.rcParams['font.family'] = 'Malgun Gothic'
# Out:
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_11984\1459182916.py", line 4
#     sns.boxplot(x='업체아이디' y='킬로미터당원가',data=df3)
#                           ^
# SyntaxError: invalid syntax

# %%
df3=df2[df2['업체아이디'].isin([1027,1009,1024,1040])]
# Out:
#         연번  업체아이디  킬로미터당원가  관할행정아이디        입력일자 최종처리자아이디        수정일자  영역분류  \
# 202    203   1024      503      6.0  2013-07-20        1  2013-07-24     1
# 206    207   1009      570      5.0  2013-07-20        1  2013-07-24     1
# 216    217   1024      503      6.0  2013-09-01        1  2013-09-01     1
# 220    221   1009      570      5.0  2013-09-01        1  2013-09-01     1
# 283    284   1027      554     30.0  2013-07-20        1  2013-07-23     2
# ...    ...    ...      ...      ...         ...      ...         ...   ...
# 3169  3170   1040      548     30.0  2012-07-10        1  2012-07-10     2
# 3187  3188   1009      554      5.0  2012-07-11        1  2012-07-11     1
# 3189  3190   1024      554      6.0  2012-07-11        1  2012-07-11     1
# 3252  3253   1009      491      5.0  2012-07-10        1  2012-07-10     1
# 3254  3255   1024      496      6.0  2012-07-10        1  2012-07-10     1
#
#       일일대당원가  평가연도  평가차수
# 202   226862  2013    26
# ...

# %%
df2[pd.Series([i in [1027,1009,1024,1040] for i in df2['업체아이디']])]
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3274    False
# 3275    False
# 3276    False
# 3277    False
# 3278    False
# Length: 3279, dtype: bool

# %%
from scipy import stats
df2_1027=df2_mask2['업체아이디']==1027
stats.shapiro(df2_1027)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11984\3875351092.py in <module>
#       1 from scipy import stats
# ----> 2 df2_1027=df2_mask2['업체아이디']==1027
#       3 stats.shapiro(df2_1027)
#
# NameError: name 'df2_mask2' is not defined

# %%
stats.probplot(df2_1040,plot=plt)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11984\772332427.py in <module>
# ----> 1 stats.probplot(df2_1040,plot=plt)
#       2 plt.show()
#
# NameError: name 'df2_1040' is not defined

# %%
# !pip install statannot

# %%
from statannot import

# %%
ax=plt.subplot()
ax=sns.boxplot(
    data=df2_mask2,
    x='업체아이디',
    y='킬로미터당원가')

add_stat_annotation(ax, #ax=figure이름
                    data=df2_mask2, 
                    x='업체아이디', #x축(column이름)
                    y='킬로미터당원가', #y축(column이름)
                    box_pairs=[(('1009'),('1040'))],#분석할 박스플롯의 쌍을 입력(리스트로 입력받음, 한쌍마다 튜플로 묶어둠)
                    test='t-test_welch',#분석할 T-test의 종류, 모를 경우 여기에 에러 발생시키면 알려줌
                    text_format='star',#T-test 결과를 별 표시로 알려줌
                    loc='inside',
                    verbose=2)

# %%
df=pd.read_csv("한국전력거래소_제주 월별 발전기별 전력거래량_20211231.csv", encoding='cp949')

# %%
df
# Out:
#           발전기       201101        201102        201103        201104  \
# 0     발전기0001  54657.31555  39325.153730  53301.020640  49592.452670
# 1     발전기0002  56520.94022  50629.928380  55969.209180  47019.531100
# 2     발전기0003  40181.46350  19984.056290  12194.137030  31749.958460
# 3     발전기0004  38286.80033  32464.780320  25407.449090   2571.340128
# 4     발전기0005  13260.89677   3637.510688   4613.547288   3071.660312
# ...       ...          ...           ...           ...           ...
# 1207  발전기1208      0.00000      0.000000      0.000000      0.000000
# 1208  발전기1209      0.00000      0.000000      0.000000      0.000000
# 1209  발전기1210      0.00000      0.000000      0.000000      0.000000
# 1210  발전기1211      0.00000      0.000000      0.000000      0.000000
# 1211  발전기1212      0.00000      0.000000      0.000000      0.000000
#
#             201105        201106        201107        201108        201109  \
# ...

# %%
sum(df['201101'])
# Out:
# 292949.2628749999

# %%
sum(df['201102'])
# Out:
# 213425.28708699998

# %%
sum(df['201103'])
# Out:
# 234374.059363

# %%
sns.histplot(df['201101','201102'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('201101', '201102')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
