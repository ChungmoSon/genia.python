# %%
import pandas as pd
import numpy as np
df=pd.read_csv('test.csv')
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df['check column'] = ''
df['Sex'] = ''
mean_sum1=0
mean_count1=0
mean_sum2=0
mean_count2=0
fare=0
count1=0
count2=0
count3=0
male_sum=0

for i in df.index:
    
    if ('Mrs' or 'Miss' or 'Ms') in df['Name'][i]:
        df['Sex'][i] = 'female'
    elif 'Mr' in df['Name'][i]:
        df['Sex'][i] = 'male'#a
    else:
        fare+=df['Fare'][i]
    
    if pd.isnull(df['Age'][i]):
        df['Age'][i] = 0 #b
    
    if df['Sex'][i] == 'male' and 10 <= df['Age'][i] and df['Age'][i] < 20:
        df['check column'][i] = 'O'
        mean_sum2 += df['Age'][i]
        mean_count2 += 1
    else:
        df['check column'][i] = 'X' #c
        
    if df['Sex'][i] == 'female' and df['Age'][i] >= 20:
        mean_sum1 += df['Age'][i]
        mean_count1 += 1
        
    if (('Master' or 'Dr' or 'Pf' or 'MD') in df['Name'][i]) and df['Pclass'][i] == 1:
        count1 +=1
    elif (('Master' or 'Dr' or 'Pf' or 'MD') in df['Name'][i]) and df['Pclass'][i] ==2:
        count2 +=1
    elif (('Master' or 'Dr' or 'Pf' or 'MD') in df['Name'][i]) and df['Pclass'][i] ==3:
        count3 +=1
    
    if df['Sex'][i] == 'male':
        male_sum += df['Fare'][i]
         
print("The percentage of the fare for people of unknown sex is", fare/df['Fare'].sum()*100,"%")
        
if mean_sum1/mean_count1 > mean_sum2/mean_count2:
    print('Number of female and over 20(',mean_sum1/mean_count1,') is bigger than male and teenager(',mean_sum2/mean_count2,')')
else: 
    print('Number of female and over 20(',mean_sum1/mean_count1,') is smaller than male and teenager(',mean_sum2/mean_count2,')')
        
df.to_csv('result.tsv', sep ='\t', index=False) #d

print("Number of people who own over a master degree in class 1 is",count1)
print("Number of people who own over a master degree in class 2 is",count2)
print("Number of people who own over a master degree in class 3 is",count3)

df[5:15]
# Out:
# The percentage of the fare for people of unknown sex is 29.810192786776906 %
# Number of female and over 20( 41.142857142857146 ) is bigger than male and teenager( 17.3125 )
# Number of people who own over a master degree in class 1 is 2
# Number of people who own over a master degree in class 2 is 2
# Number of people who own over a master degree in class 3 is 17
# So most of people who own over a master degree are in 17
# C:\Users\user\AppData\Local\Temp\ipykernel_8012\1045887006.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sex'][i] = 'male'#a
# C:\Users\user\AppData\Local\Temp\ipykernel_8012\1045887006.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
x = df['Sex']=='male'
df[x]
# Out:
#      PassengerId  Pclass                          Name   Sex   Age  SibSp  \
# 0            892       3              Kelly, Mr. James  male  34.5      0
# 2            894       2     Myles, Mr. Thomas Francis  male  62.0      0
# 3            895       3              Wirz, Mr. Albert  male  27.0      0
# 5            897       3    Svensson, Mr. Johan Cervin  male  14.0      0
# 7            899       2  Caldwell, Mr. Albert Francis  male  26.0      1
# ..           ...     ...                           ...   ...   ...    ...
# 406         1298       2     Ware, Mr. William Jeffery  male  23.0      1
# 407         1299       1    Widener, Mr. George Dunton  male  50.0      1
# 413         1305       3            Spector, Mr. Woolf  male   0.0      0
# 415         1307       3  Saether, Mr. Simon Sivertsen  male  38.5      0
# 416         1308       3           Ware, Mr. Frederick  male   0.0      0
#
#      Parch              Ticket      Fare Cabin Embarked check column
# ...

# %%
def strlen(x,y,z):
    x=str(x)
    if z==1:
        if len(x)>y:
            return "long"
        else:
            return "short"
    else:    
        if len(x)<y:
            return "long"
        else:
            return "short"

# %%
strlen('a',2,0)
# Out:
# 'long'
